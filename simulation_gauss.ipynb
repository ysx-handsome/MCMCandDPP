# %%
import numpy as np
import pickle
import time
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal as mvn
from scipy.stats import skewnorm
from scipy.stats import norm
from scipy.interpolate import griddata
from pp_mix.src.proto.proto import *
from pp_mix.src.proto.Params import *
from pp_mix.interface import ConditionalMCMC
from pp_mix.params_helper import *
from sklearn.datasets import make_blobs  # 用于创建模拟数据

np.random.seed(0)
num_samples = 1000
num_features = 2
num_clusters = 4

data, labels = make_blobs(n_samples=num_samples, n_features=num_features, centers=num_clusters, random_state=0)

nrep = 10
# dimrange = [1, 2, 3, 4, 5]
# strauss_times = np.zeros((nrep, len(dimrange)))

# nrange = [5, 10, 20]
#dpp_times = np.zeros((nrep, len(dimrange), len(nrange)))

dim = 2

# prec_params = WishartParams(
#     nu=dim+1,identity=True, sigma=3, dim=dim)
prec_params = WishartParams()
# WishartParams.nu = dim+1
# WishartParams.identity = True
# WishartParams.sigma = 3
# WishartParams.dim = dim
prec_params.nu = dim+1
prec_params.identity = True
prec_params.sigma = 3
prec_params.dim = dim
# gamma_jump_params = GammaParams(alpha=1, beta=1)
gamma_jump_params = GammaParams()
gamma_jump_params.alpha = 1
gamma_jump_params.beta = 1


strauss_params = make_default_strauss(data)
strauss_params.fixed_params = False
strauss_sampler = ConditionalMCMC(
    pp_params=strauss_params,
    prec_params=prec_params,
    jump_params=gamma_jump_params)

start = time.time()
strauss_sampler.run(1, 10000, 5, data)
strauss_times = time.time() - start

print(strauss_sampler.chains)
# print(strauss_sampler.chains[19].clus_alloc)
# Out:
# ranges:
#  [[-9.04303375 -4.29695879]
#  [ 9.29938422 20.75138327]]
# AdaptiveMetropolis::init()
# initialize
#  beta: 0.03373619725628426, vol_range: 459.44715944867545, c_star: 15.500000000000002
# initialize done
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_means begin
# sample_means end
# init npoints: 15
# /data/cyw/MCMCandDPP/Python_code/pp_mix/src/jump/gamma.py:36: RuntimeWarning: invalid value encountered in log
#   num = np.log(prop) * nh - u * prop + gamma.logpdf(prop, a=self.alpha, scale=1 / self.beta)
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_means begin
# sample_means end
# init npoints: 20
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_means begin
# sample_means end
# init npoints: 20
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_means begin
# sample_means end
# init npoints: 15
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_means begin
# sample_means end
# init npoints: 19
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_means begin
# sample_means end
# init npoints: 12
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_means begin
# sample_means end
# init npoints: 23
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_given_active begin
# sample_given_active end
# sample_means begin
# sample_means end
# init npoints: 14
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-487394173883> in <module>
#      54
#      55 start = time.time()
# ---> 56 strauss_sampler.run(1, 10000, 5, data)
#      57 strauss_times = time.time() - start
#      58
#
# ~/MCMCandDPP/Python_code/pp_mix/interface.py in run(self, nburn, niter, thin, data, log_every, bernoulli)
#      27         #out = pp_mix_py._run_pp_mix(
#      28         #    nburn, niter, thin, data, self.serialized_params, bernoulli, log_every)
# ---> 29         out = pp_mix_py._run_pp_mix(
#      30             nburn, niter, thin, data, self.params, bernoulli, log_every)
#      31
#
# ~/MCMCandDPP/Python_code/pp_mix/src/python_exports.py in _run_pp_mix(burnin, niter, thin, data, params, bernoulli, log_every)
#     163         return run_pp_mix_univ(burnin, niter, thin, data, params, log_every)
#     164     else:
# --> 165         return run_pp_mix_multi(burnin, niter, thin, data, params, log_every)
#     166
#     167
#
# ~/MCMCandDPP/Python_code/pp_mix/src/python_exports.py in run_pp_mix_multi(burnin, niter, thin, data, params, log_every)
#     104
#     105     for i in range(niter):
# --> 106         sampler.run_one()
#     107         if i % thin == 0:
#     108             s = ""
#
# ~/MCMCandDPP/Python_code/pp_mix/src/conditional_mcmc_imp.py in run_one(self)
#      71         self.sample_jumps()
#      72
# ---> 73         self.pp_mix.update_hypers(self.a_means, self.na_means)
#      74
#      75     def sample_allocations_and_relabel(self):
#
# ~/MCMCandDPP/Python_code/pp_mix/src/point_process/strauss_pp.py in update_hypers(self, active, non_active)
#     170         sampler = PerfectSampler(self)
#     171         #aux_var, aux_dists = sampler.simulate(self.vol_range, self.beta, self.gamma, self.R)
# --> 172         aux_var = sampler.simulate()
#     173         self.beta = old_beta
#     174
#
# ~/MCMCandDPP/Python_code/pp_mix/src/point_process/perfect_sampler.py in simulate(self)
#     115             # print("iter:", iter)
#     116             for i in range(start_t, end_t):
# --> 117                 self.one_backward(self.state)
#     118
#     119             self.in_upper = [p.number for p in self.state][::-1]
#
# ~/MCMCandDPP/Python_code/pp_mix/src/point_process/perfect_sampler.py in one_backward(self, points)
#      54         cstar = self.pp.get_cstar()
#      55
# ---> 56         if rsec > cstar / (cstar + len(points)):
#      57             if len(points) == 0:
#      58                 return
#
# KeyboardInterrupt:

# %%
strauss_times
# Out:
# 206.84496021270752

# %%
strauss_sampler.run(1,5,2,data)
# Out:
# ranges:
#  [[-9.04303375 -4.29695879]
#  [ 9.29938422 20.75138327]]
# AdaptiveMetropolis::init()
# initialize
#  beta: 0.03373619725628426, vol_range: 459.44715944867545, c_star: 15.500000000000002
# initialize done
# sample_means-------------------------------------
# init npoints: 14
# /data/cyw/MCMCandDPP/Python_code/pp_mix/src/jump/gamma.py:36: RuntimeWarning: invalid value encountered in log
#   num = np.log(prop) * nh - u * prop + gamma.logpdf(prop, a=self.alpha, scale=1 / self.beta)
# sample_means-------------------------------------
# init npoints: 8
# sample_means-------------------------------------
# init npoints: 17
# sample_means-------------------------------------
# init npoints: 11
# sample_means-------------------------------------
# init npoints: 13
# sample_means-------------------------------------
# init npoints: 12
